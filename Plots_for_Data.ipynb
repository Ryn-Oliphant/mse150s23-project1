# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt(fname='mod_data/mod_tensiletest-pekk_bulk.txt', delimiter=' ', usecols=range(6))

# %%
print(data.dtype)
# Out:
# float64

# %%
print(data.shape)
# Out:
# (3000, 6)

# %%
print(data[0])
# Out:
# [ 0.    12.019  0.     0.     0.     0.   ]

# %%
img = plt.imshow(data)

# %%
plt.plot(data[:,5],data[:,1])
