# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt(fname='mod_data/mod_tensiletest-pps_bulk.txt', delimiter=' ', usecols=range(6))

# %%
def youngs_modulus (data):
    
    lin_fit = np.polyfit(data[0:200,5],data[0:200,1],1)
    lin_func = np.poly1d(lin_fit)
    
    print("Young's Modulus = ",lin_fit[0])
    plt.plot(data[:,5],data[:,1],'b')
    plt.plot(data[:,5],lin_func(data[:,5]),'y')

# %%
youngs_modulus(data)
# Out:
# Young's Modulus =  3798.4149658615943

# %%
plt.plot(data[0:200,5],data[0:200,1])
